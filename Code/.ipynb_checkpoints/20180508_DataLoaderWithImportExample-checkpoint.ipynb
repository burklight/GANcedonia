# %%
import database as db
from torchvision import transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import numpy as np

# %%
fruits_file = 'Dataset/dataset_index.csv'
textures_file = 'Dataset/textures_index.csv'
fruits_path = 'Dataset/fruits-360'
textures_path = 'Dataset/textures'

# %%
fruits_avocado_orange = db.FruitsDataset(path_to_file=fruits_path, csv_file=fruits_file,
    cl_A='Lemon', cl_B='Raspberry')

# %%
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(10,25))
for i in range(len(fruits_avocado_orange)):
    sample = fruits_avocado_orange[i]
    ax[i,0].imshow(sample[0])
    ax[i,1].imshow(sample[1])
    if i == 5:
        plt.show()
        break

# %%
textures = db.TexturesDataset(path_to_file=textures_path,csv_file=textures_file, force=True)

# %%
fig, ax = plt.subplots(nrows=6, ncols=1, figsize=(10,25))

print(len(textures))
for i in range(len(textures)):
    sample = textures[i]
    ax[i].imshow(sample)
    if i == 5:
        plt.show()
        break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-8cd407ef450a> in <module>()
#       2
#       3 for i in range(len(textures)):
# ----> 4     sample = textures[i]
#       5     ax[i].imshow(sample)
#       6     if i == 5:
#
# /media/burklight/BorjaData/GANcedonia/Code/database.py in __getitem__(self, idx)
#     100     def __getitem__(self, idx):
#     101         img_name = self.textures.iloc[idx, 0]
# --> 102         image = io.imread(img_name)
#     103
#     104         if self.transform:
#
# /usr/local/lib/python3.5/dist-packages/skimage/io/_io.py in imread(fname, as_grey, plugin, flatten, **plugin_args)
#      59
#      60     with file_or_url_context(fname) as fname:
# ---> 61         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      62
#      63     if not hasattr(img, 'ndim'):
#
# ...

# %%
test = db.FruitsDataset(path_to_file=fruits_path, csv_file=fruits_file, cl_A='Orange', cl_B='Raspberry', 
                        transform = transforms.Compose([db.ChangeBackground(textures)]))

# %%
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(10,25))

for i in range(len(test)):
    sample = test[i]
    ax[i,0].imshow(sample[0]+0.5)
    ax[i,1].imshow(sample[1]+0.5)
    if i == 5:
        plt.show()
        break

# %% [markdown]
# ## Use dataloader for loading batches of data randomly

# %%
dataloader = DataLoader(test, batch_size=20,
                        shuffle=True, num_workers=4)

# %%
for i_batch, sample_batched in enumerate(dataloader):
    if i_batch == 5:
        n_elems = len(sample_batched[0])
        for j in range(n_elems):
            print(sample_batched[0][j].shape)
            fig, ax = plt.subplots(nrows=1, ncols=2)
            ax[0].imshow(np.array((sample_batched[0][j]+0.5) * 255.0).astype(int))
            ax[1].imshow(np.array((sample_batched[1][j]+0.5) * 255.0).astype(int))
# Out:
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])
# torch.Size([128, 128, 3])

# %%
imgs = next(iter(dataloader))

# %%
plt.imshow(imgs[0][0]+0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /anaconda/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /anaconda/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
# ...
